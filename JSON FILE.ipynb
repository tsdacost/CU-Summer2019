# %%
import pandas as pd
from pandas import DataFrame
import json

# %%
df = pd.read_json("filename.json", orient='columns', typ='frame', convert_axes=True)
df = pd.DataFrame(df)

# %%
print(df, sep=' ')
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$1,465,000', 'IM...
#
#                                            A Ciambra  \
# 0  {'Genre': 'Drama', 'Gross': 'unknown', 'IMDB M...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 72, 'rating': 'R', 'tomatosco...
#
#                  Along With The Gods: The Two Worlds  \
# 0  {'popcornscore': 90, 'rating': 'NR', 'tomatosc...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'Genre': 'Animation', 'Gross': 'unknown', 'IM...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                               Condorito: La Película  \
# 0  {'popcornscore': 59, 'rating': 'PG', 'tomatosc...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# ...

# %%
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$1,465,000', 'IM...
#
#                                            A Ciambra  \
# 0  {'Genre': 'Drama', 'Gross': 'unknown', 'IMDB M...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 72, 'rating': 'R', 'tomatosco...
#
#                  Along With The Gods: The Two Worlds  \
# 0  {'popcornscore': 90, 'rating': 'NR', 'tomatosc...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'Genre': 'Animation', 'Gross': 'unknown', 'IM...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                               Condorito: La Película  \
# 0  {'popcornscore': 59, 'rating': 'PG', 'tomatosc...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# ...
